# %%
if __name__ == '__main__':
    AE = AutoEncoders()

    AE.Train()
    # AE.Test()
# Out:
# 0. Loss = [[0.10698248 0.0727248  0.02148425]],
# xi = [0.1 0.2 0.3], xi_hat = [0.66652223 0.66709142 0.55387547]
# 1. Loss = [[0.10184664 0.06982486 0.02097127]],
# xi = [0.1 0.2 0.3], xi_hat = [0.65275666 0.65768394 0.55082624]
# 2. Loss = [[0.09700763 0.06707888 0.02048024]],
# xi = [0.1 0.2 0.3], xi_hat = [0.63946536 0.64859406 0.54787239]
# 3. Loss = [[0.09245262 0.06447763 0.02000944]],
# xi = [0.1 0.2 0.3], xi_hat = [0.62664775 0.63981005 0.54500678]
# 4. Loss = [[0.08816777 0.06201237 0.01955733]],
# xi = [0.1 0.2 0.3], xi_hat = [0.61429885 0.63132019 0.54222304]
# 5. Loss = [[0.08413869 0.05967484 0.01912256]],
# xi = [0.1 0.2 0.3], xi_hat = [0.60241026 0.62311288 0.53951553]
# 6. Loss = [[0.08035083 0.05745725 0.01870392]],
# xi = [0.1 0.2 0.3], xi_hat = [0.59097095 0.61517678 0.53687923]
# 7. Loss = [[0.07678977 0.05535232 0.01830034]],
# xi = [0.1 0.2 0.3], xi_hat = [0.57996803 0.60750085 0.53430966]
# 8. Loss = [[0.07344146 0.05335319 0.01791085]],
# ...
